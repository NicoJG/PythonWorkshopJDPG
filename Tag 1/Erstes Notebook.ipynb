# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.animation import FuncAnimation

# %%
# %matplotlib notebook

# %%
fig = plt.figure()
lines = [plt.plot([],'-')[0] for i in range(2)]

plt.axis("scaled")
plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)

x = np.linspace(0,2*np.pi,100)
def animieren(frame):
    x = np.sin(2*np.pi*frame/100)
    y = np.cos(2*np.pi*frame/100)
    x2 = 0.5*np.cos(np.pi+2*np.pi*frame/100)
    y2 = 0.5*np.sin(np.pi+2*np.pi*frame/100)
    
    lines[0].set_data((0,x),(0,y))
    lines[1].set_data((0,x2),(0,y2))
    return line
    
anim = FuncAnimation(fig, animieren, interval=20, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()

plt.subplot(1,2,1)
lines = [plt.plot([],'-')[0] for i in range(2)]
plt.axis("scaled")
plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)

plt.subplot(1,2,2)
lines2 = [plt.plot([],'-')[0] for i in range(2)]
plt.axis("scaled")
plt.xlim(0,6*np.pi,50)
plt.ylim(-1.5,1.5)

linsp = np.linspace(0,2*np.pi,100)
dx,dy = [],[]

def animieren(frame):
    x = np.sin(2*np.pi*frames/100)
    y = np.cos(2*np.pi*frames/100)
    x2 = 0.5*np.cos(np.pi+2*np.pi*frames/100)
    y2 = 0.5*np.sin(np.pi+2*np.pi*frames/100)
    
    lines[0].set_data((0,x),(0,y))
    lines[1].set_data((0,x2),(0,y2))
    
    dx.append(linsp[frames])
    dy.append(y)
    lines2[0].set_data(dx,dy)
    return [*lines,lines2[0]]
    
anim = FuncAnimation(fig, animieren, interval=20, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
